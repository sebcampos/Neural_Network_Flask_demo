# %%
import pandas
from connect_sql_db import build_engine

# %%
engine = build_engine(database_name="database1",host="35.225.193.21")
df_1 = pandas.read_sql("select * from cleaned_table", con=engine)

# %%
for i in df_1.columns:
    print(f'"{i}",')
# Out:
# "address",
# "city",
# "state",
# "postal_code",
# "latitude",
# "longitude",
# "stars",
# "review_count",
# "is_open",
# "business_id",
# "name",
# "byob",
# "bikeparking",
# "businessacceptsbitcoin",
# "businessacceptscreditcards",
# "caters",
# "coatcheck",
# "corkage",
# "dogsallowed",
# "drivethru",
# "goodfordancing",
# "goodforkids",
# "happyhour",
# "hastv",
# "outdoorseating",
# "restaurantsdelivery",
# "restaurantsgoodforgroups",
# "restaurantsreservations",
# "restaurantstableservice",
# "restaurantstakeout",
# "smoking",
# "wheelchairaccessible",
# "alcohol_false",
# "alcohol_beer_and_wine",
# "alcohol_full_bar",
# "byobcorkage_false",
# "byobcorkage_yes_corkage",
# "byobcorkage_yes_free",
# "noiselevel_average",
# "noiselevel_loud",
# "noiselevel_quiet",
# "noiselevel_very_loud",
# "restaurantsattire_casual",
# "restaurantsattire_dressy",
# "restaurantsattire_formal",
# "restaurantsattire_no_dress_code",
# "restaurantspricerange2_$10_and_under",
# "restaurantspricerange2_$11_to_30",
# "restaurantspricerange2_$31_to_60",
# "restaurantspricerange2_$61_and_over",
# "wifi_false",
# "wifi_free",
# "wifi_paid",
# "hipster",
# "classy",
# "intimate",
# "trendy",
# "casual",
# "touristy",
# "divey",
# "romantic",
# "upscale",
# "beer_bar",
# "thai",
# "food_stands",
# "salvadoran",
# "cuban",
# "donuts",
# "diners",
# "salad",
# "irish",
# "italian",
# "persian_iranian",
# "szechuan",
# "cafes",
# "vietnamese",
# "turkish",
# "tacos",
# "chicken_shop",
# "canadian_new",
# "belgian",
# "indian",
# "moroccan",
# "southern",
# "pan_asian",
# "tapas_small_plates",
# "desserts",
# "irish_pub",
# "local_flavor",
# "comfort_food",
# "ramen",
# "pizza",
# "bagels",
# "poke",
# "fish___chips",
# "peruvian",
# "waffles",
# "cantonese",
# "falafel",
# "american_traditional",
# "sandwiches",
# "french",
# "modern_european",
# "burgers",
# "dim_sum",
# "beer",
# "brasseries",
# "creperies",
# "tea_rooms",
# "jazz___blues",
# "brazilian",
# "street_vendors",
# "bistros",
# "taiwanese",
# "chicken_wings",
# "filipino",
# "fast_food",
# "vegan",
# "breakfast___brunch",
# "british",
# "asian_fusion",
# "colombian",
# "barbeque",
# "lounges",
# "cheesesteaks",
# "hungarian",
# "kebab",
# "arcades",
# "seafood",
# "bubble_tea",
# "juice_bars___smoothies",
# "sushi_bars",
# "cafeteria",
# "ice_cream___frozen_yogurt",
# "bakeries",
# "poutineries",
# "soup",
# "tapas_bars",
# "seafood_markets",
# "venezuelan",
# "internet_cafes",
# "acai_bowls",
# "themed_cafes",
# "hot_dogs",
# "himalayan_nepalese",
# "tex_mex",
# "american_new",
# "buffets",
# "coffee___tea",
# "delis",
# "wraps",
# "arabian",
# "steakhouses",
# "karaoke",
# "cajun_creole",
# "ethnic_food",
# "polish",
# "argentine",
# "latin_american",
# "caribbean",
# "halal",
# "hookah_bars",
# "do_it_yourself_food",
# "afghan",
# "noodles",
# "food",
# "chinese",
# "mediterranean",
# "new_mexican_cuisine",
# "vegetarian",
# "food_trucks",
# "ethiopian",
# "spanish",
# "german",
# "food_delivery_services",
# "african",
# "korean",
# "cocktail_bars",
# "dive_bars",
# "soul_food",
# "mongolian",
# "lebanese",
# "middle_eastern",
# "portuguese",
# "malaysian",
# "gastropubs",
# "japanese",
# "hot_pot",
# "hawaiian",
# "wine_bars",
# "greek",
# "sports_bars",
# "gluten_free",
# "pakistani",
# "mexican",
# "smokehouse",
# "hakka",
# "kosher",
# "caterers",

# %%
for column in df_1.drop([
    "address",
    "city",
    "state",
    "postal_code",
    "latitude",
    "longitude",
    "stars",
    "review_count",
    "is_open",
    "business_id",
    "name",
], axis = 1).columns:
    print(column)
# Out:
# byob
# bikeparking
# businessacceptsbitcoin
# businessacceptscreditcards
# caters
# coatcheck
# corkage
# dogsallowed
# drivethru
# goodfordancing
# goodforkids
# happyhour
# hastv
# outdoorseating
# restaurantsdelivery
# restaurantsgoodforgroups
# restaurantsreservations
# restaurantstableservice
# restaurantstakeout
# smoking
# wheelchairaccessible
# alcohol_false
# alcohol_beer_and_wine
# alcohol_full_bar
# byobcorkage_false
# byobcorkage_yes_corkage
# byobcorkage_yes_free
# noiselevel_average
# noiselevel_loud
# noiselevel_quiet
# noiselevel_very_loud
# restaurantsattire_casual
# restaurantsattire_dressy
# restaurantsattire_formal
# restaurantsattire_no_dress_code
# restaurantspricerange2_$10_and_under
# restaurantspricerange2_$11_to_30
# restaurantspricerange2_$31_to_60
# restaurantspricerange2_$61_and_over
# wifi_false
# wifi_free
# wifi_paid
# hipster
# classy
# intimate
# trendy
# casual
# touristy
# divey
# romantic
# upscale
# beer_bar
# thai
# food_stands
# salvadoran
# cuban
# donuts
# diners
# salad
# irish
# italian
# persian_iranian
# szechuan
# cafes
# vietnamese
# turkish
# tacos
# chicken_shop
# canadian_new
# belgian
# indian
# moroccan
# southern
# pan_asian
# tapas_small_plates
# desserts
# irish_pub
# local_flavor
# comfort_food
# ramen
# pizza
# bagels
# poke
# fish___chips
# peruvian
# waffles
# cantonese
# falafel
# american_traditional
# sandwiches
# french
# modern_european
# burgers
# dim_sum
# beer
# brasseries
# creperies
# tea_rooms
# jazz___blues
# brazilian
# street_vendors
# bistros
# taiwanese
# chicken_wings
# filipino
# fast_food
# vegan
# breakfast___brunch
# british
# asian_fusion
# colombian
# barbeque
# lounges
# cheesesteaks
# hungarian
# kebab
# arcades
# seafood
# bubble_tea
# juice_bars___smoothies
# sushi_bars
# cafeteria
# ice_cream___frozen_yogurt
# bakeries
# poutineries
# soup
# tapas_bars
# seafood_markets
# venezuelan
# internet_cafes
# acai_bowls
# themed_cafes
# hot_dogs
# himalayan_nepalese
# tex_mex
# american_new
# buffets
# coffee___tea
# delis
# wraps
# arabian
# steakhouses
# karaoke
# cajun_creole
# ethnic_food
# polish
# argentine
# latin_american
# caribbean
# halal
# hookah_bars
# do_it_yourself_food
# afghan
# noodles
# food
# chinese
# mediterranean
# new_mexican_cuisine
# vegetarian
# food_trucks
# ethiopian
# spanish
# german
# food_delivery_services
# african
# korean
# cocktail_bars
# dive_bars
# soul_food
# mongolian
# lebanese
# middle_eastern
# portuguese
# malaysian
# gastropubs
# japanese
# hot_pot
# hawaiian
# wine_bars
# greek
# sports_bars
# gluten_free
# pakistani
# mexican
# smokehouse
# hakka
# kosher
# caterers
